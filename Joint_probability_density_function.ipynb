# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.random.random(10000)
y = np.random.random(10000)
bins = 100
plt.hist(x, bins=bins, normed=1, color='b', histtype='stepfilled', alpha=0.5); 
plt.hist(y, bins=bins, normed=1, color='g', histtype='stepfilled', alpha=0.5);

# %%
z = x*y
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

xp = np.linspace(0.01, 1, 1000)
zfit = -np.log(xp)
plt.plot(xp, zfit, 'b')

# %%
z = x + y
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

# %%
z = x / y
plt.hist(z, bins=20, normed=1, color='r', histtype='stepfilled', alpha=0.5);

# %%
z = x - y
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

# %%
z = x**y
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

xp = np.linspace(0.01, 0.99, 1000)
zfit = -np.log(1.0 - xp) #?
plt.plot(xp, zfit, 'b')

# %%
z = y*y
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5); #?

# %%
z = x**x
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5); #?

# %%
x = np.random.random(1000000)
z = np.sqrt(x)
plt.hist(z, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

# %%
x2 = np.random.random(1000000)
plt.hist(x2, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

# %%
z2 = z*x2
plt.hist(z2, bins=bins, normed=1, color='r', histtype='stepfilled', alpha=0.5);

# %%
z3 = z2*z1
